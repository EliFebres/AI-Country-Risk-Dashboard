# %%
import sys
import requests
import pandas as pd
from pathlib import Path
import xml.etree.ElementTree as ET

# find the project root by looking for a directory that contains "DataFetching"
cwd = Path().resolve()
project_root = cwd
while not (project_root / "DataFetching").exists():
    if project_root.parent == project_root:
        raise RuntimeError("Could not find project root containing DataFetching/")
    project_root = project_root.parent

sys.path.insert(0, str(project_root)) # add project root to sys.path

import DataFetching.Utility.constants as constants



# --- Fetch the XML data from the World Bank API ---
url = "https://api.worldbank.org/v2/country?format=xml&per_page=300"
response = requests.get(url)
response.raise_for_status()

# --- Parse the XML response ---
root = ET.fromstring(response.content)
ns = {'wb': 'http://www.worldbank.org'}  # World Bank XML namespace

# --- Extract relevant data ---
wb_countries = []
for country in root.findall('wb:country', ns):
    country_data = {
        'id': country.get('id'),
        'name': country.find('wb:name', ns).text,
        'iso2Code': country.find('wb:iso2Code', ns).text,
        'longitude': country.find('wb:longitude', ns).text,
        'latitude': country.find('wb:latitude', ns).text,
    }
    wb_countries.append(country_data)

# --- Filter to selected countries only ---
filtered_countries = [c for c in wb_countries if c['name'] in constants.SELECTED_COUNTRIES]

# Optional: Save to Excel
# pd.DataFrame(filtered_countries).to_excel("country_data.xlsx", index=False)

# Show filtered countries
for c in filtered_countries:
    print(c)
# Out:
# {'id': 'ARE', 'name': 'United Arab Emirates', 'iso2Code': 'AE', 'longitude': '54.3705', 'latitude': '24.4764'}
# {'id': 'ARG', 'name': 'Argentina', 'iso2Code': 'AR', 'longitude': '-58.4173', 'latitude': '-34.6118'}
# {'id': 'AUS', 'name': 'Australia', 'iso2Code': 'AU', 'longitude': '149.129', 'latitude': '-35.282'}
# {'id': 'AUT', 'name': 'Austria', 'iso2Code': 'AT', 'longitude': '16.3798', 'latitude': '48.2201'}
# {'id': 'BEL', 'name': 'Belgium', 'iso2Code': 'BE', 'longitude': '4.36761', 'latitude': '50.8371'}
# {'id': 'BGD', 'name': 'Bangladesh', 'iso2Code': 'BD', 'longitude': '90.4113', 'latitude': '23.7055'}
# {'id': 'BRA', 'name': 'Brazil', 'iso2Code': 'BR', 'longitude': '-47.9292', 'latitude': '-15.7801'}
# {'id': 'CAN', 'name': 'Canada', 'iso2Code': 'CA', 'longitude': '-75.6919', 'latitude': '45.4215'}
# {'id': 'CHE', 'name': 'Switzerland', 'iso2Code': 'CH', 'longitude': '7.44821', 'latitude': '46.948'}
# {'id': 'CHL', 'name': 'Chile', 'iso2Code': 'CL', 'longitude': '-70.6475', 'latitude': '-33.475'}
# {'id': 'CHN', 'name': 'China', 'iso2Code': 'CN', 'longitude': '116.286', 'latitude': '40.0495'}
# {'id': 'COL', 'name': 'Colombia', 'iso2Code': 'CO', 'longitude': '-74.082', 'latitude': '4.60987'}
# {'id': 'DEU', 'name': 'Germany', 'iso2Code': 'DE', 'longitude': '13.4115', 'latitude': '52.5235'}
# {'id': 'DNK', 'name': 'Denmark', 'iso2Code': 'DK', 'longitude': '12.5681', 'latitude': '55.6763'}
# {'id': 'ESP', 'name': 'Spain', 'iso2Code': 'ES', 'longitude': '-3.70327', 'latitude': '40.4167'}
# {'id': 'FIN', 'name': 'Finland', 'iso2Code': 'FI', 'longitude': '24.9525', 'latitude': '60.1608'}
# {'id': 'FRA', 'name': 'France', 'iso2Code': 'FR', 'longitude': '2.35097', 'latitude': '48.8566'}
# {'id': 'GBR', 'name': 'United Kingdom', 'iso2Code': 'GB', 'longitude': '-0.126236', 'latitude': '51.5002'}
# {'id': 'GRC', 'name': 'Greece', 'iso2Code': 'GR', 'longitude': '23.7166', 'latitude': '37.9792'}
# {'id': 'HKG', 'name': 'Hong Kong SAR, China', 'iso2Code': 'HK', 'longitude': '114.109', 'latitude': '22.3964'}
# {'id': 'HUN', 'name': 'Hungary', 'iso2Code': 'HU', 'longitude': '19.0408', 'latitude': '47.4984'}
# {'id': 'IDN', 'name': 'Indonesia', 'iso2Code': 'ID', 'longitude': '106.83', 'latitude': '-6.19752'}
# {'id': 'IND', 'name': 'India', 'iso2Code': 'IN', 'longitude': '77.225', 'latitude': '28.6353'}
# {'id': 'IRL', 'name': 'Ireland', 'iso2Code': 'IE', 'longitude': '-6.26749', 'latitude': '53.3441'}
# {'id': 'ISR', 'name': 'Israel', 'iso2Code': 'IL', 'longitude': '35.2035', 'latitude': '31.7717'}
# {'id': 'ITA', 'name': 'Italy', 'iso2Code': 'IT', 'longitude': '12.4823', 'latitude': '41.8955'}
# {'id': 'JPN', 'name': 'Japan', 'iso2Code': 'JP', 'longitude': '139.77', 'latitude': '35.67'}
# {'id': 'KEN', 'name': 'Kenya', 'iso2Code': 'KE', 'longitude': '36.8126', 'latitude': '-1.27975'}
# {'id': 'LUX', 'name': 'Luxembourg', 'iso2Code': 'LU', 'longitude': '6.1296', 'latitude': '49.61'}
# {'id': 'MAR', 'name': 'Morocco', 'iso2Code': 'MA', 'longitude': '-6.8704', 'latitude': '33.9905'}
# {'id': 'MEX', 'name': 'Mexico', 'iso2Code': 'MX', 'longitude': '-99.1276', 'latitude': '19.427'}
# {'id': 'MYS', 'name': 'Malaysia', 'iso2Code': 'MY', 'longitude': '101.684', 'latitude': '3.12433'}
# {'id': 'NGA', 'name': 'Nigeria', 'iso2Code': 'NG', 'longitude': '7.48906', 'latitude': '9.05804'}
# {'id': 'NLD', 'name': 'Netherlands', 'iso2Code': 'NL', 'longitude': '4.89095', 'latitude': '52.3738'}
# {'id': 'NOR', 'name': 'Norway', 'iso2Code': 'NO', 'longitude': '10.7387', 'latitude': '59.9138'}
# {'id': 'NZL', 'name': 'New Zealand', 'iso2Code': 'NZ', 'longitude': '174.776', 'latitude': '-41.2865'}
# {'id': 'PAK', 'name': 'Pakistan', 'iso2Code': 'PK', 'longitude': '72.8', 'latitude': '30.5167'}
# {'id': 'PER', 'name': 'Peru', 'iso2Code': 'PE', 'longitude': '-77.0465', 'latitude': '-12.0931'}
# {'id': 'PHL', 'name': 'Philippines', 'iso2Code': 'PH', 'longitude': '121.035', 'latitude': '14.5515'}
# {'id': 'POL', 'name': 'Poland', 'iso2Code': 'PL', 'longitude': '21.02', 'latitude': '52.26'}
# {'id': 'PRT', 'name': 'Portugal', 'iso2Code': 'PT', 'longitude': '-9.13552', 'latitude': '38.7072'}
# {'id': 'QAT', 'name': 'Qatar', 'iso2Code': 'QA', 'longitude': '51.5082', 'latitude': '25.2948'}
# {'id': 'ROU', 'name': 'Romania', 'iso2Code': 'RO', 'longitude': '26.0979', 'latitude': '44.4479'}
# {'id': 'SAU', 'name': 'Saudi Arabia', 'iso2Code': 'SA', 'longitude': '46.6977', 'latitude': '24.6748'}
# {'id': 'SGP', 'name': 'Singapore', 'iso2Code': 'SG', 'longitude': '103.85', 'latitude': '1.28941'}
# {'id': 'SWE', 'name': 'Sweden', 'iso2Code': 'SE', 'longitude': '18.0645', 'latitude': '59.3327'}
# {'id': 'THA', 'name': 'Thailand', 'iso2Code': 'TH', 'longitude': '100.521', 'latitude': '13.7308'}
# {'id': 'UKR', 'name': 'Ukraine', 'iso2Code': 'UA', 'longitude': '30.5038', 'latitude': '50.4536'}
# {'id': 'USA', 'name': 'United States', 'iso2Code': 'US', 'longitude': '-77.032', 'latitude': '38.8895'}
# {'id': 'ZAF', 'name': 'South Africa', 'iso2Code': 'ZA', 'longitude': '28.1871', 'latitude': '-25.746'}
